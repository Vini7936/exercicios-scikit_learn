# %%
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd

# %%
transacoes = [
    ['Leite', 'Pão', 'Manteiga'],
    ['Pão', 'Manteiga'],
    ['Leite', 'Pão'],
    ['Leite', 'Café'],
    ['Leite', 'Pão', 'Manteiga', 'Café']
]

# %%
te = TransactionEncoder()
dados = pd.DataFrame(te.fit(transacoes).transform(transacoes), columns=te.columns_)

# %%
frequent_itemsets = apriori(dados, min_support=0.4, use_colnames=True)

# %%
regras = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)

# %%
print(regras[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
#          antecedents   consequents  support  confidence      lift
# 0             (Café)       (Leite)      0.4    1.000000  1.250000
# 1         (Manteiga)       (Leite)      0.4    0.666667  0.833333
# 2              (Pão)       (Leite)      0.6    0.750000  0.937500
# 3            (Leite)         (Pão)      0.6    0.750000  0.937500
# 4              (Pão)    (Manteiga)      0.6    0.750000  1.250000
# 5         (Manteiga)         (Pão)      0.6    1.000000  1.250000
# 6       (Pão, Leite)    (Manteiga)      0.4    0.666667  1.111111
# 7    (Pão, Manteiga)       (Leite)      0.4    0.666667  0.833333
# 8  (Leite, Manteiga)         (Pão)      0.4    1.000000  1.250000
# 9         (Manteiga)  (Pão, Leite)      0.4    0.666667  1.111111
